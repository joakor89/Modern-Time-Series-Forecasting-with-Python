# %% [markdown]
# # Experimental Study
#
# ### Loading Libraries

# %%
# %cd ../..
# Out:
# /Users/joaquinromero/Desktop

# %%
# Installing darts library to recreate experiments
# !pip install darts
# Out:
# Collecting darts
#   Downloading darts-0.37.1-py3-none-any.whl.metadata (60 kB)
# Collecting holidays>=0.11.1 (from darts)
#   Downloading holidays-0.80-py3-none-any.whl.metadata (48 kB)
# Requirement already satisfied: joblib>=0.16.0 in /opt/anaconda3/lib/python3.12/site-packages (from darts) (1.4.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from darts) (3.7.5)
# Requirement already satisfied: narwhals>=1.25.1 in /opt/anaconda3/lib/python3.12/site-packages (from darts) (2.3.0)
# Collecting nfoursid>=1.0.0 (from darts)
#   Downloading nfoursid-1.0.2-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: numpy>=1.19.0 in /opt/anaconda3/lib/python3.12/site-packages (from darts) (1.26.4)
# Requirement already satisfied: pandas>=1.0.5 in /opt/anaconda3/lib/python3.12/site-packages (from darts) (2.3.2)
# Collecting pyod>=0.9.5 (from darts)
#   Downloading pyod-2.0.5-py3-none-any.whl.metadata (46 kB)
# Requirement already satisfied: requests>=2.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from darts) (2.32.3)
# Requirement already satisfied: scikit-learn>=1.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from darts) (1.6.1)
# Requirement already satisfied: scipy>=1.3.2 in /opt/anaconda3/lib/python3.12/site-packages (from darts) (1.11.4)
# Collecting shap>=0.40.0 (from darts)
#   Downloading shap-0.48.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (25 kB)
# Requirement already satisfied: statsforecast>=1.4 in /opt/anaconda3/lib/python3.12/site-packages (from darts) (2.0.2)
# Requirement already satisfied: statsmodels>=0.14.0 in /opt/anaconda3/lib/python3.12/site-packages (from darts) (0.14.2)
# Requirement already satisfied: tqdm>=4.60.0 in /opt/anaconda3/lib/python3.12/site-packages (from darts) (4.66.5)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/lib/python3.12/site-packages (from darts) (4.11.0)
# Requirement already satisfied: xarray>=0.17.0 in /opt/anaconda3/lib/python3.12/site-packages (from darts) (2023.6.0)
# Requirement already satisfied: xgboost>=2.1.4 in /opt/anaconda3/lib/python3.12/site-packages (from darts) (3.0.0)
# Collecting pytorch-lightning<2.5.3,>=1.5.0 (from darts)
#   Using cached pytorch_lightning-2.5.2-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: tensorboardX>=2.1 in /opt/anaconda3/lib/python3.12/site-packages (from darts) (2.6.4)
# Requirement already satisfied: torch>=1.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from darts) (2.6.0)
# Requirement already satisfied: python-dateutil in /opt/anaconda3/lib/python3.12/site-packages (from holidays>=0.11.1->darts) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->darts) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->darts) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->darts) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->darts) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->darts) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->darts) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->darts) (3.2.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.0.5->darts) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.0.5->darts) (2025.2)
# Requirement already satisfied: numba>=0.51 in /opt/anaconda3/lib/python3.12/site-packages (from pyod>=0.9.5->darts) (0.60.0)
# Requirement already satisfied: PyYAML>=5.4 in /opt/anaconda3/lib/python3.12/site-packages (from pytorch-lightning<2.5.3,>=1.5.0->darts) (6.0.1)
# Requirement already satisfied: fsspec>=2022.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning<2.5.3,>=1.5.0->darts) (2024.6.1)
# Requirement already satisfied: torchmetrics>=0.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from pytorch-lightning<2.5.3,>=1.5.0->darts) (1.8.1)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /opt/anaconda3/lib/python3.12/site-packages (from pytorch-lightning<2.5.3,>=1.5.0->darts) (0.15.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.22.0->darts) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.22.0->darts) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.22.0->darts) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.22.0->darts) (2025.1.31)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn>=1.6.0->darts) (3.5.0)
# Collecting slicer==0.0.8 (from shap>=0.40.0->darts)
#   Using cached slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: cloudpickle in /opt/anaconda3/lib/python3.12/site-packages (from shap>=0.40.0->darts) (3.0.0)
# Requirement already satisfied: coreforecast>=0.0.12 in /opt/anaconda3/lib/python3.12/site-packages (from statsforecast>=1.4->darts) (0.0.16)
# Requirement already satisfied: fugue>=0.8.1 in /opt/anaconda3/lib/python3.12/site-packages (from statsforecast>=1.4->darts) (0.9.1)
# Requirement already satisfied: utilsforecast>=0.1.4 in /opt/anaconda3/lib/python3.12/site-packages (from statsforecast>=1.4->darts) (0.2.12)
# Requirement already satisfied: patsy>=0.5.6 in /opt/anaconda3/lib/python3.12/site-packages (from statsmodels>=0.14.0->darts) (0.5.6)
# Requirement already satisfied: protobuf>=3.20 in /opt/anaconda3/lib/python3.12/site-packages (from tensorboardX>=2.1->darts) (4.25.3)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->darts) (3.13.1)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->darts) (3.3)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->darts) (3.1.4)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->darts) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->darts) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.8.0->darts) (1.3.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/anaconda3/lib/python3.12/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning<2.5.3,>=1.5.0->darts) (3.10.5)
# Requirement already satisfied: triad>=0.9.7 in /opt/anaconda3/lib/python3.12/site-packages (from fugue>=0.8.1->statsforecast>=1.4->darts) (0.9.8)
# Requirement already satisfied: adagio>=0.2.4 in /opt/anaconda3/lib/python3.12/site-packages (from fugue>=0.8.1->statsforecast>=1.4->darts) (0.2.6)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /opt/anaconda3/lib/python3.12/site-packages (from numba>=0.51->pyod>=0.9.5->darts) (0.43.0)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.12/site-packages (from patsy>=0.5.6->statsmodels>=0.14.0->darts) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2->torch>=1.8.0->darts) (2.1.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.5.3,>=1.5.0->darts) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.5.3,>=1.5.0->darts) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.5.3,>=1.5.0->darts) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.5.3,>=1.5.0->darts) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.5.3,>=1.5.0->darts) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<2.5.3,>=1.5.0->darts) (1.11.0)
# Requirement already satisfied: pyarrow>=6.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from triad>=0.9.7->fugue>=0.8.1->statsforecast>=1.4->darts) (16.1.0)
# Requirement already satisfied: fs in /opt/anaconda3/lib/python3.12/site-packages (from triad>=0.9.7->fugue>=0.8.1->statsforecast>=1.4->darts) (2.4.16)
# Requirement already satisfied: appdirs~=1.4.3 in /opt/anaconda3/lib/python3.12/site-packages (from fs->triad>=0.9.7->fugue>=0.8.1->statsforecast>=1.4->darts) (1.4.4)
# Downloading darts-0.37.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 15.0 MB/s eta 0:00:00
# Downloading holidays-0.80-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 28.2 MB/s eta 0:00:00
# Downloading nfoursid-1.0.2-py3-none-any.whl (18 kB)
# Downloading pyod-2.0.5-py3-none-any.whl (200 kB)
# Using cached pytorch_lightning-2.5.2-py3-none-any.whl (825 kB)
# Downloading shap-0.48.0-cp312-cp312-macosx_11_0_arm64.whl (547 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.6/547.6 kB 23.7 MB/s eta 0:00:00
# Using cached slicer-0.0.8-py3-none-any.whl (15 kB)
# Installing collected packages: slicer, holidays, shap, pyod, nfoursid, pytorch-lightning, darts
#   Attempting uninstall: pytorch-lightning
#     Found existing installation: pytorch-lightning 2.5.4
#     Uninstalling pytorch-lightning-2.5.4:
#       Successfully uninstalled pytorch-lightning-2.5.4
# Successfully installed darts-0.37.1 holidays-0.80 nfoursid-1.0.2 pyod-2.0.5 pytorch-lightning-2.5.2 shap-0.48.0 slicer-0.0.8

# %%
# Numerical Computing
import numpy as np

# Data Manipulation
import pandas as pd

# Data Visualization
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Notebook Optimizer
from tqdm.autonotebook import tqdm

# OS
import os
import random
import warnings
from pathlib import Path

# DARTS
from darts import TimeSeries
from darts.models import (
    NaiveSeasonal,
    ExponentialSmoothing,
    Theta, 
    FFT,
    LightGBMModel
)
from darts.metrics import mase
from darts.utils.utils import ModelMode, SeasonalityMode

# %%
# Custom 
import plotly.figure_factory as ff
from src.utils.ts_utils import rmsse

# %%
np.random.seed()

# %%
os.makedirs("imgs/chapter_19", exist_ok=True)

preprocessed = Path.home() / "Desktop" / "data" / "london_smart_meters" / "preprocessed"

output = Path.home() / "Desktop" / "data" / "london_smart_meters" / "output"

# %%
from darts.metrics.metrics import _get_values_or_raise


def rmsse(
    actual_series,
    pred_series,
    insample,
    m=1,
    intersect=True,
    *,
    reduction=np.mean,
):

    def _multivariate_mase(
        actual_series,
        pred_series,
        insample,
        m,
        intersect,
        reduction,
    ):

        assert (
            actual_series.width == pred_series.width
        ), "The two TimeSeries instances must have the same width."

        assert (
            actual_series.width == insample.width
        ), "The insample TimeSeries must have the same width as the other series."

        assert (
            insample.end_time() + insample.freq == pred_series.start_time()
        ), "The pred_series must be the forecast of the insample series"

        insample_ = (
            insample.quantile_timeseries(quantile=0.5)
            if insample.is_stochastic
            else insample
        )

        value_list = []
        for i in range(actual_series.width):
            # old implementation of mase on univariate TimeSeries
            y_true, y_hat = _get_values_or_raise(
                actual_series.univariate_component(i),
                pred_series.univariate_component(i),
                intersect,
                remove_nan_union=False,
            )

            x_t = insample_.univariate_component(i).values()
            errors = np.square(y_true - y_hat)
            scale = np.mean(np.square(x_t[m:] - x_t[:-m]))
            assert not np.isclose(scale, 0), "cannot use MASE with periodical signals"
            value_list.append(np.sqrt(np.mean(errors / scale)))

        return reduction(value_list)

    return _multivariate_mase(
        actual_series=actual_series,
        pred_series=pred_series,
        insample=insample,
        m=m,
        intersect=intersect,
        reduction=reduction,
    )

# %%
from itertools import cycle

def format_plot(
    fig,
    legends=None,
    xlabel="Time",
    ylabel="Value",
    title="",
    font_size=15,
    title_font_size=20,
    width=900,
    height=500,
):
    # Renombrar trazas si se proveen leyendas
    if legends:
        names = cycle(legends)
        fig.for_each_trace(lambda t: t.update(name=next(names)))

    fig.update_layout(
        autosize=False,
        width=width,
        height=height,
        # Título (API moderna)
        title=dict(
            text=title,
            x=0.5,
            xanchor="center",
            yanchor="top",
            font=dict(size=title_font_size),
        ),
        legend_title_text=None,
        legend=dict(
            font=dict(size=font_size),
            orientation="h",
            yanchor="bottom",
            y=0.9,
            xanchor="right",
            x=1,
        ),
        # Ejes (API moderna)
        yaxis=dict(
            title=dict(text=ylabel, font=dict(size=font_size)),
            tickfont=dict(size=font_size),
        ),
        xaxis=dict(
            title=dict(text=xlabel, font=dict(size=font_size)),
            tickfont=dict(size=font_size),
        ),
        margin=dict(t=60, r=30, b=50, l=60),
        template="plotly_white",
    )
    return fig

# %%
def format_y_pred(y_pred, name):
    y_pred = y_pred.data_array().to_series()
    y_pred.index = y_pred.index.get_level_values(0)
    y_pred.name = name
    return y_pred

# %% [markdown]
# ### Reading Files

# %%
# Reading the missing value imputed and train test split data
try:
    train_df = pd.read_parquet(preprocessed/"selected_blocks_train_missing_imputed.parquet")
    val_df = pd.read_parquet(preprocessed/"selected_blocks_val_missing_imputed.parquet")
    test_df = pd.read_parquet(preprocessed/"selected_blocks_test_missing_imputed.parquet")
except FileNotFoundError:
    display(HTML("""
    <div class="alert alert-block alert-warning">
    <b>Warning!</b> File not found. Please make sure you have run 01-Setting up Experiment Harness.ipynb in Chapter04
    </div>
    """))
