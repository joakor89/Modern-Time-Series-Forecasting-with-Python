# %% [markdown]
# # Quantiles & Weighted Quantiles
#
# ### Loading Libraries

# %%
# Numerical Computing
import numpy as np

# Data Visualization
import matplotlib.pyplot as plt

# %% [markdown]
# ### Quantiles
